# %% [markdown]
# # Load and Inspect Data

# %% [markdown]
# ### Checking out dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('../data/zillow_data.csv')

# %%
df
# Out:
#        RegionID  RegionName                 City State              Metro  \
# 0         84654       60657              Chicago    IL            Chicago
# 1         90668       75070             McKinney    TX  Dallas-Fort Worth
# 2         91982       77494                 Katy    TX            Houston
# 3         84616       60614              Chicago    IL            Chicago
# 4         93144       79936              El Paso    TX            El Paso
# ...         ...         ...                  ...   ...                ...
# 14718     58333        1338             Ashfield    MA    Greenfield Town
# 14719     59107        3293            Woodstock    NH          Claremont
# 14720     75672       40404                Berea    KY           Richmond
# 14721     93733       81225  Mount Crested Butte    CO                NaN
# 14722     95851       89155             Mesquite    NV          Las Vegas
#
#       CountyName  SizeRank   1996-04   1996-05   1996-06  ...  2017-07  \
# ...

# %%
cities = df.City.unique().tolist()

# %%
len(cities)
# Out:
# 7554

# %%
df[df.CountyName == 'Orleans']
# Out:
#        RegionID  RegionName         City State        Metro CountyName  \
# 1038      88479       70115  New Orleans    LA  New Orleans    Orleans
# 1723      88482       70118  New Orleans    LA  New Orleans    Orleans
# 1862      88485       70122  New Orleans    LA  New Orleans    Orleans
# 3984      88494       70131  New Orleans    LA  New Orleans    Orleans
# 4000      88493       70130  New Orleans    LA  New Orleans    Orleans
# 7796      63508       14411       Albion    NY    Rochester    Orleans
# 8124      63419       14103       Medina    NY    Rochester    Orleans
# 9406      63544       14470       Murray    NY    Rochester    Orleans
# 12703     63416       14098        Yates    NY    Rochester    Orleans
# 13639     63548       14476      Kendall    NY    Rochester    Orleans
# 14115     63549       14477      Carlton    NY    Rochester    Orleans
# 14269     63613       14571      Carlton    NY    Rochester    Orleans
#
# ...

# %% [markdown]
# ### Limiting to New Orleans zip codes

# %%
df = df[(df.CountyName == 'Orleans') & (df.State == 'LA')]
df
# Out:
#       RegionID  RegionName         City State        Metro CountyName  \
# 1038     88479       70115  New Orleans    LA  New Orleans    Orleans
# 1723     88482       70118  New Orleans    LA  New Orleans    Orleans
# 1862     88485       70122  New Orleans    LA  New Orleans    Orleans
# 3984     88494       70131  New Orleans    LA  New Orleans    Orleans
# 4000     88493       70130  New Orleans    LA  New Orleans    Orleans
#
#       SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 1038      1039  131700.0  132900.0  134200.0  ...   594100   598100   603200
# 1723      1724   87900.0   88700.0   89700.0  ...   392200   397200   403300
# 1862      1863       NaN       NaN       NaN  ...   165000   166500   168400
# 3984      3985   90900.0   91900.0   92800.0  ...   160700   162600   163400
# 4000      4001  111600.0  112800.0  114100.0  ...   583400   590100   595000
#
#       2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# ...

# %%
df.iloc[:,6:10]
# Out:
#       SizeRank   1996-04   1996-05   1996-06
# 1038      1039  131700.0  132900.0  134200.0
# 1723      1724   87900.0   88700.0   89700.0
# 1862      1863       NaN       NaN       NaN
# 3984      3985   90900.0   91900.0   92800.0
# 4000      4001  111600.0  112800.0  114100.0

# %%
df.SizeRank
# Out:
# 1038    1039
# 1723    1724
# 1862    1863
# 3984    3985
# 4000    4001
# Name: SizeRank, dtype: int64

# %%
df[df.RegionName == 70118]
# Out:
#       RegionID  RegionName         City State        Metro CountyName  \
# 1723     88482       70118  New Orleans    LA  New Orleans    Orleans
#
#       SizeRank  1996-04  1996-05  1996-06  ...  2017-07  2017-08  2017-09  \
# 1723      1724  87900.0  88700.0  89700.0  ...   392200   397200   403300
#
#       2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# 1723   406100   405400   404000   405500   409200   411200   409700
#
# [1 rows x 272 columns]

# %%
df70118 = df[df.RegionName == 70118]

# %%
df70118 = df70118.drop(columns=['RegionID', 'CountyName', 'City', 'State', 'Metro', 'SizeRank', 'RegionName'])

# %%
df70118
# Out:
#       1996-04  1996-05  1996-06  1996-07  1996-08  1996-09  1996-10  1996-11  \
# 1723  87900.0  88700.0  89700.0  90800.0  91900.0  93100.0  94400.0  95700.0
#
#       1996-12  1997-01  ...  2017-07  2017-08  2017-09  2017-10  2017-11  \
# 1723  97200.0  98600.0  ...   392200   397200   403300   406100   405400
#
#       2017-12  2018-01  2018-02  2018-03  2018-04
# 1723   404000   405500   409200   411200   409700
#
# [1 rows x 265 columns]

# %%
def get_datetimes(df):
    return pd.to_datetime(df.columns.values[1:], format='%Y-%m')

#index.values -- no [1:]

# %%
df70118 = df70118.transpose()
df70118
# Out:
#              1723
# 1996-04   87900.0
# 1996-05   88700.0
# 1996-06   89700.0
# 1996-07   90800.0
# 1996-08   91900.0
# ...           ...
# 2017-12  404000.0
# 2018-01  405500.0
# 2018-02  409200.0
# 2018-03  411200.0
# 2018-04  409700.0
#
# [265 rows x 1 columns]

# %%
df70118.index
# Out:
# Index(['1996-04', '1996-05', '1996-06', '1996-07', '1996-08', '1996-09',
#        '1996-10', '1996-11', '1996-12', '1997-01',
#        ...
#        '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#        '2018-01', '2018-02', '2018-03', '2018-04'],
#       dtype='object', length=265)

# %%
df
# Out:
#       RegionID  RegionName         City State        Metro CountyName  \
# 1038     88479       70115  New Orleans    LA  New Orleans    Orleans
# 1723     88482       70118  New Orleans    LA  New Orleans    Orleans
# 1862     88485       70122  New Orleans    LA  New Orleans    Orleans
# 3984     88494       70131  New Orleans    LA  New Orleans    Orleans
# 4000     88493       70130  New Orleans    LA  New Orleans    Orleans
#
#       SizeRank   1996-04   1996-05   1996-06  ...  2017-07  2017-08  2017-09  \
# 1038      1039  131700.0  132900.0  134200.0  ...   594100   598100   603200
# 1723      1724   87900.0   88700.0   89700.0  ...   392200   397200   403300
# 1862      1863       NaN       NaN       NaN  ...   165000   166500   168400
# 3984      3985   90900.0   91900.0   92800.0  ...   160700   162600   163400
# 4000      4001  111600.0  112800.0  114100.0  ...   583400   590100   595000
#
#       2017-10  2017-11  2017-12  2018-01  2018-02  2018-03  2018-04
# ...

# %%
df =  df.drop(columns=['RegionID', 'CountyName', 'City', 'State', 'Metro', 'SizeRank'])

# %%
df.head()
# Out:
#       RegionName   1996-04   1996-05   1996-06   1996-07   1996-08   1996-09  \
# 1038       70115  131700.0  132900.0  134200.0  135700.0  137300.0  139000.0
# 1723       70118   87900.0   88700.0   89700.0   90800.0   91900.0   93100.0
# 1862       70122       NaN       NaN       NaN       NaN       NaN       NaN
# 3984       70131   90900.0   91900.0   92800.0   93800.0   94600.0   95300.0
# 4000       70130  111600.0  112800.0  114100.0  115400.0  116800.0  118100.0
#
#        1996-10   1996-11   1996-12  ...  2017-07  2017-08  2017-09  2017-10  \
# 1038  141000.0  143000.0  145200.0  ...   594100   598100   603200   603000
# 1723   94400.0   95700.0   97200.0  ...   392200   397200   403300   406100
# 1862       NaN       NaN       NaN  ...   165000   166500   168400   169700
# 3984   95900.0   96400.0   96800.0  ...   160700   162600   163400   164400
# 4000  119400.0  120800.0  122400.0  ...   583400   590100   595000   593900
#
# ...

# %%
df = df.set_index('RegionName')
df.index.name = None

# %%
df.head()
# Out:
#         1996-04   1996-05   1996-06   1996-07   1996-08   1996-09   1996-10  \
# 70115  131700.0  132900.0  134200.0  135700.0  137300.0  139000.0  141000.0
# 70118   87900.0   88700.0   89700.0   90800.0   91900.0   93100.0   94400.0
# 70122       NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 70131   90900.0   91900.0   92800.0   93800.0   94600.0   95300.0   95900.0
# 70130  111600.0  112800.0  114100.0  115400.0  116800.0  118100.0  119400.0
#
#         1996-11   1996-12   1997-01  ...  2017-07  2017-08  2017-09  2017-10  \
# 70115  143000.0  145200.0  147400.0  ...   594100   598100   603200   603000
# 70118   95700.0   97200.0   98600.0  ...   392200   397200   403300   406100
# 70122       NaN       NaN       NaN  ...   165000   166500   168400   169700
# 70131   96400.0   96800.0   97300.0  ...   160700   162600   163400   164400
# 70130  120800.0  122400.0  124000.0  ...   583400   590100   595000   593900
#
# ...

# %%
df = df.transpose()
df.head()
# Out:
#             70115    70118  70122    70131     70130
# 1996-04  131700.0  87900.0    NaN  90900.0  111600.0
# 1996-05  132900.0  88700.0    NaN  91900.0  112800.0
# 1996-06  134200.0  89700.0    NaN  92800.0  114100.0
# 1996-07  135700.0  90800.0    NaN  93800.0  115400.0
# 1996-08  137300.0  91900.0    NaN  94600.0  116800.0

# %%
df = df.rename_axis('date')

# %%
df
# Out:
#             70115     70118     70122     70131     70130
# date
# 1996-04  131700.0   87900.0       NaN   90900.0  111600.0
# 1996-05  132900.0   88700.0       NaN   91900.0  112800.0
# 1996-06  134200.0   89700.0       NaN   92800.0  114100.0
# 1996-07  135700.0   90800.0       NaN   93800.0  115400.0
# 1996-08  137300.0   91900.0       NaN   94600.0  116800.0
# ...           ...       ...       ...       ...       ...
# 2017-12  596700.0  404000.0  172000.0  164600.0  599300.0
# 2018-01  599800.0  405500.0  173100.0  164100.0  602400.0
# 2018-02  603200.0  409200.0  174600.0  165000.0  598300.0
# 2018-03  599600.0  411200.0  176300.0  166900.0  590500.0
# 2018-04  592300.0  409700.0  177100.0  167800.0  587100.0
#
# [265 rows x 5 columns]

# %%
df.axes
# Out:
# [Index(['1996-04', '1996-05', '1996-06', '1996-07', '1996-08', '1996-09',
#         '1996-10', '1996-11', '1996-12', '1997-01',
#         ...
#         '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#         '2018-01', '2018-02', '2018-03', '2018-04'],
#        dtype='object', name='date', length=265),
#  Int64Index([70115, 70118, 70122, 70131, 70130], dtype='int64')]

# %%
df70118.axes
# Out:
# [Index(['1996-04', '1996-05', '1996-06', '1996-07', '1996-08', '1996-09',
#         '1996-10', '1996-11', '1996-12', '1997-01',
#         ...
#         '2017-07', '2017-08', '2017-09', '2017-10', '2017-11', '2017-12',
#         '2018-01', '2018-02', '2018-03', '2018-04'],
#        dtype='object', length=265), Int64Index([1723], dtype='int64')]

# %%
df.iloc[:,2]
# Out:
# date
# 1996-04         NaN
# 1996-05         NaN
# 1996-06         NaN
# 1996-07         NaN
# 1996-08         NaN
#              ...
# 2017-12    172000.0
# 2018-01    173100.0
# 2018-02    174600.0
# 2018-03    176300.0
# 2018-04    177100.0
# Name: 70122, Length: 265, dtype: float64

# %%
df.iloc[:,2].isna().sum()
# Out:
# 207
